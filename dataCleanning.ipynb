# %%
import pandas as pd
import numpy as np
import os
import csv
from unidecode import unidecode

# %%
print(os.getcwd())
# Out:
# C:\Users\LACINE BERTHE\Desktop\2022-2023\Pole_emploi\Formation\Data_Scientest\Projet\Satisfaction_client

# %%
df=pd.read_csv('C:/Users/LACINE BERTHE/Desktop/2022-2023/Pole_emploi/Formation/Data_Scientest/Projet/Satisfaction_client/infos_company2.csv')
df.head()
# Out:
#    Unnamed: 0     Name_company Note trust pilot Nombre avis  \
# 0           0         Immoprêt              4,9       5 265
# 1           1  Younited Credit              4,8      60 845
# 2           2    CIB Formation              4,8         498
# 3           3          Cofidis              4,7      17 699
# 4           4           Pixpay              4,7       3 065
#
#               Localisation company       Domaine d activité  \
# 0                    Lille, France                   Banque
# 1                    Paris, France  Agence de crédit·Banque
# 2            SAINT ETIENNE, France                   Banque
# 3  Villeneuve d'Ascq Cedex, France                   Banque
# 4                              NaN                   Banque
#
#   nombre d'avis excellent
# 0                    82 %
# 1                    81 %
# 2                    79 %
# 3                    86 %
# 4                    85 %

# %%
df=df.drop(df.columns[0], axis=1)
df.head()
# Out:
#       Name_company Note trust pilot Nombre avis  \
# 0         Immoprêt              4,9       5 265
# 1  Younited Credit              4,8      60 845
# 2    CIB Formation              4,8         498
# 3          Cofidis              4,7      17 699
# 4           Pixpay              4,7       3 065
#
#               Localisation company       Domaine d activité  \
# 0                    Lille, France                   Banque
# 1                    Paris, France  Agence de crédit·Banque
# 2            SAINT ETIENNE, France                   Banque
# 3  Villeneuve d'Ascq Cedex, France                   Banque
# 4                              NaN                   Banque
#
#   nombre d'avis excellent
# 0                    82 %
# 1                    81 %
# 2                    79 %
# 3                    86 %
# 4                    85 %

# %%
df.columns
# Out:
# Index(['Name_company', 'Note trust pilot', 'Nombre avis',
#        'Localisation company', 'Domaine d activité',
#        'nombre d'avis excellent'],
#       dtype='object')

# %%
df.to_csv('informat_company.csv',index=False)

# %%
# ouvrir le fichier CSV original et créer un nouveau fichier pour écrire les données modifiées
with open('informat_company.csv', 'r', encoding='utf-8') as fichier_original, \
     open('info_company_sans_accents3.csv', 'w', encoding='utf-8', newline='') as fichier_modifie:
     
    # créer un objet writer pour écrire les données modifiées
    writer = csv.writer(fichier_modifie, delimiter=',')

    # parcourir chaque ligne du fichier original, supprimer les accents et écrire les données modifiées dans le nouveau fichier
    reader = csv.reader(fichier_original)
    for ligne in reader:
        nouvelle_ligne = [unidecode(cellule) for cellule in ligne]
        writer.writerow(nouvelle_ligne)

# %%
data=pd.read_csv('C:/Users/LACINE BERTHE/Desktop/2022-2023/Pole_emploi/Formation/Data_Scientest/Projet/Satisfaction_client/info_company_sans_accents3.csv')
data.head()
# Out:
#       Name_company Note trust pilot Nombre avis  \
# 0         Immopret              4,9       5 265
# 1  Younited Credit              4,8      60 845
# 2    CIB Formation              4,8         498
# 3          Cofidis              4,7      17 699
# 4           Pixpay              4,7       3 065
#
#               Localisation company       Domaine d activite  \
# 0                    Lille, France                   Banque
# 1                    Paris, France  Agence de credit*Banque
# 2            SAINT ETIENNE, France                   Banque
# 3  Villeneuve d'Ascq Cedex, France                   Banque
# 4                              NaN                   Banque
#
#   nombre d'avis excellent
# 0                    82 %
# 1                    81 %
# 2                    79 %
# 3                    86 %
# 4                    85 %

# %%
data.shape
# Out:
# (360, 6)

# %%
data.insert(0, 'id', range(360))

# %%
data.head(20)
# Out:
#     id                   Name_company Note trust pilot Nombre avis  \
# 0    0                       Immopret              4,9       5 265
# 1    1                Younited Credit              4,8      60 845
# 2    2                  CIB Formation              4,8         498
# 3    3                        Cofidis              4,7      17 699
# 4    4                         Pixpay              4,7       3 065
# 5    5                        Anytime              4,5       5 820
# 6    6                          Shine              4,5       2 013
# 7    7                    Orange Bank              4,4      12 670
# 8    8                      Helios.do              4,3         394
# 9    9                        Paykrom              4,2          71
# 10  10              Boursorama Banque              4,1       4 634
# 11  11                       Monabanq              4,1       3 811
# 12  12                        ONLYONE              4,4          23
# 13  13  Plusq1taux Landes Pays Basque              4,4          12
# 14  14                         la Nef              4,3          67
# 15  15                       MoneyNow              4,3           8
# 16  16                       Floabank              4,2       6 089
# 17  17                 Ma French Bank              4,2       2 347
# 18  18                          Blank              4,0         194
# 19  19                        Cosabnk              4,0           9
#
#                Localisation company  \
# 0                     Lille, France
# 1                     Paris, France
# 2             SAINT ETIENNE, France
# 3   Villeneuve d'Ascq Cedex, France
# 4                               NaN
# 5                               NaN
# 6                     Paris, France
# 7                 Montreuil, France
# 8                               NaN
# 9                   Puteaux, France
# 10     Boulogne-Billancourt, France
# 11        Villeneuve-d'Ascq, France
# 12                    PARIS, France
# 13                   Anglet, France
# 14           Vaulx en Velin, France
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                    Paris, France
# 19                              NaN
#
#                                    Domaine d activite nombre d'avis excellent
# 0                                              Banque                    82 %
# 1                             Agence de credit*Banque                    81 %
# 2                                              Banque                    79 %
# 3                                              Banque                    86 %
# 4                                              Banque                    85 %
# 5                                              Banque                    73 %
# 6   Banque*Banque du secteur prive*Institution fin...                    78 %
# 7                      Banque*Banque du secteur prive                    62 %
# 8                                              Banque                    70 %
# 9                       Institution financiere*Banque                    74 %
# 10  Service de transfert d'argent*Banque*Instituti...                    68 %
# 11                                             Banque                    62 %
# 12                                             Banque                    83 %
# 13  Service de conseil en credit*Courtier d'assura...                   100 %
# 14                            Banque*Banque d'epargne                    75 %
# 15                 Banque*Site de comparaison de prix                   100 %
# 16                     Etablissement de credit*Banque                    48 %
# 17                                             Banque                    62 %
# 18                                             Banque                    66 %
# 19                                             Banque                    78 %

# %%
data['Note trust pilot'] = data['Note trust pilot'].str.strip('"')
data['Note trust pilot'] = data['Note trust pilot'].replace(',', '.', regex=True)
data['Nombre avis'] = data['Nombre avis'].str.replace(' ', '')

# %%
data.dtypes
# Out:
# id                          int64
# Name_company               object
# Note trust pilot           object
# Nombre avis                object
# Localisation company       object
# Domaine d activite         object
# nombre d'avis excellent    object
# dtype: object

# %%
data['Nombre avis']
# Out:
# 0       5265
# 1      60845
# 2        498
# 3      17699
# 4       3065
#        ...
# 355        3
# 356        2
# 357      NaN
# 358      NaN
# 359      NaN
# Name: Nombre avis, Length: 360, dtype: object

# %%
data.head()
# Out:
#    id     Name_company Note trust pilot Nombre avis  \
# 0   0         Immopret              4.9        5265
# 1   1  Younited Credit              4.8       60845
# 2   2    CIB Formation              4.8         498
# 3   3          Cofidis              4.7       17699
# 4   4           Pixpay              4.7        3065
#
#               Localisation company       Domaine d activite  \
# 0                    Lille, France                   Banque
# 1                    Paris, France  Agence de credit*Banque
# 2            SAINT ETIENNE, France                   Banque
# 3  Villeneuve d'Ascq Cedex, France                   Banque
# 4                              NaN                   Banque
#
#   nombre d'avis excellent
# 0                    82 %
# 1                    81 %
# 2                    79 %
# 3                    86 %
# 4                    85 %

# %%
data.isna().sum()
# Out:
# id                           0
# Name_company                 0
# Note trust pilot            40
# Nombre avis                 40
# Localisation company       118
# Domaine d activite          38
# nombre d'avis excellent     38
# dtype: int64

# %%
'''data = data.astype({"Name_company": str, 
                    "Note trust pilot": float, 
                    "Nombre avis": int, 
                    "Localisation company": str, 
                    "Domaine d activite": str, 
                    "nombre d'avis excellent": str})
data.dtypes'''
# Out:
# 'data = data.astype({"Name_company": str, \n                    "Note trust pilot": float, \n                    "Nombre avis": int, \n                    "Localisation company": str, \n                    "Domaine d activite": str, \n                    "nombre d\'avis excellent": str})\ndata.dtypes'

# %%
data.to_csv('infoss_company.csv',index=False)
