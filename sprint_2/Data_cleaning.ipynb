# %%
import pandas as pd
import numpy as np
import os
import csv
from unidecode import unidecode

# %%
print(os.getcwd())
# Out:
# C:\Users\LACINE BERTHE\Desktop\2022-2023\Pole_emploi\Formation\Data_Scientest\Projet\Satisfaction_client

# %%
df=pd.read_csv('C:/Users/LACINE BERTHE/Desktop/2022-2023/Pole_emploi/Formation/Data_Scientest/Projet/Satisfaction_client/infos_company.csv')
df.head()
# Out:
#    Unnamed: 0        Name_company Note trust pilot Nombre avis  \
# 0           0            Immoprêt              4,9       5 257
# 1           1     Younited Credit              4,8      60 705
# 2           2             Cofidis              4,8      17 591
# 3           3  Empruntis l'agence              4,8       6 269
# 4           4       CIB Formation              4,8         498
#
#       Localisation company       Domaine d activité
# 0                    Lille                   Banque
# 1                    Paris  Agence de crédit·Banque
# 2  Villeneuve d'Ascq Cedex                   Banque
# 3        Saint Denis Cedex                   Banque
# 4            SAINT ETIENNE                   Banque

# %%
df=df.drop(df.columns[0], axis=1)
df.head()
# Out:
#          Name_company Note trust pilot Nombre avis     Localisation company  \
# 0            Immoprêt              4,9       5 257                    Lille
# 1     Younited Credit              4,8      60 705                    Paris
# 2             Cofidis              4,8      17 591  Villeneuve d'Ascq Cedex
# 3  Empruntis l'agence              4,8       6 269        Saint Denis Cedex
# 4       CIB Formation              4,8         498            SAINT ETIENNE
#
#         Domaine d activité
# 0                   Banque
# 1  Agence de crédit·Banque
# 2                   Banque
# 3                   Banque
# 4                   Banque

# %%
df.columns
# Out:
# Index(['Name_company', 'Note trust pilot', 'Nombre avis',
#        'Localisation company', 'Domaine d activité'],
#       dtype='object')

# %%
# ouvrir le fichier CSV original et créer un nouveau fichier pour écrire les données modifiées
with open('info_company.csv', 'r', encoding='utf-8') as fichier_original, \
     open('info_company_sans_accents.csv', 'w', encoding='utf-8', newline='') as fichier_modifie:
     
    # créer un objet writer pour écrire les données modifiées
    writer = csv.writer(fichier_modifie, delimiter=',')

    # parcourir chaque ligne du fichier original, supprimer les accents et écrire les données modifiées dans le nouveau fichier
    reader = csv.reader(fichier_original)
    for ligne in reader:
        nouvelle_ligne = [unidecode(cellule) for cellule in ligne]
        writer.writerow(nouvelle_ligne)

# %%
data=pd.read_csv('C:/Users/LACINE BERTHE/Desktop/2022-2023/Pole_emploi/Formation/Data_Scientest/Projet/Satisfaction_client/info_company_sans_accents.csv')
data.head()
# Out:
#          Name_company Note trust pilot Nombre avis     Localisation company  \
# 0            Immopret              4,9       5 257                    Lille
# 1     Younited Credit              4,8      60 705                    Paris
# 2             Cofidis              4,8      17 591  Villeneuve d'Ascq Cedex
# 3  Empruntis l'agence              4,8       6 269        Saint Denis Cedex
# 4       CIB Formation              4,8         498            SAINT ETIENNE
#
#         Domaine d activite
# 0                   Banque
# 1  Agence de credit*Banque
# 2                   Banque
# 3                   Banque
# 4                   Banque

# %%
data.insert(0, 'id', range(180))

# %%
data.head(20)
# Out:
#     id                                    Name_company Note trust pilot  \
# 0    0                                        Immopret              4,9
# 1    1                                 Younited Credit              4,8
# 2    2                                         Cofidis              4,8
# 3    3                              Empruntis l'agence              4,8
# 4    4                                   CIB Formation              4,8
# 5    5                                          Pixpay              4,7
# 6    6                                         Anytime              4,5
# 7    7                                           Shine              4,5
# 8    8                                     Orange Bank              4,4
# 9    9                                       Helios.do              4,3
# 10  10                                         Paykrom              4,2
# 11  11                                        Monabanq              4,1
# 12  12                               Boursorama Banque              3,9
# 13  13                                        Fortuneo              3,0
# 14  14  France SCPI - Le site tout en ligne de la SCPI              4,9
# 15  15                                            Kard              4,8
# 16  16                                       Green-Got              4,8
# 17  17                                   ConnectBanque              4,8
# 18  18                                            Vybe              4,7
# 19  19                                    bcfinance.fr              4,7
#
#    Nombre avis     Localisation company  \
# 0        5 257                    Lille
# 1       60 705                    Paris
# 2       17 591  Villeneuve d'Ascq Cedex
# 3        6 269        Saint Denis Cedex
# 4          498            SAINT ETIENNE
# 5        3 035                      NaN
# 6        5 783                      NaN
# 7        1 972                    Paris
# 8       12 611                Montreuil
# 9          384                      NaN
# 10          69                  Puteaux
# 11       3 801        Villeneuve-d'Ascq
# 12       4 882     Boulogne-Billancourt
# 13         989                      NaN
# 14         230                    PARIS
# 15       1 007                      NaN
# 16         267                    Paris
# 17          52                      NaN
# 18         933                      NaN
# 19         555              Lille Cedex
#
#                                    Domaine d activite
# 0                                              Banque
# 1                             Agence de credit*Banque
# 2                                              Banque
# 3                                              Banque
# 4                                              Banque
# 5                                              Banque
# 6                                              Banque
# 7   Institution financiere*Banque du secteur prive...
# 8                      Banque*Banque du secteur prive
# 9                                              Banque
# 10                      Banque*Institution financiere
# 11                                             Banque
# 12  Service de transfert d'argent*Banque*Instituti...
# 13                                             Banque
# 14  Investissements immobiliers*Conseiller financi...
# 15                                             Banque
# 16                                             Banque
# 17                         Service de paiement*Banque
# 18                                             Banque
# 19            Societe financiere non banquiere*Banque

# %%
data['Note trust pilot'] = data['Note trust pilot'].str.strip('"')
data['Note trust pilot'] = data['Note trust pilot'].replace(',', '.', regex=True)
data['Nombre avis'] = data['Nombre avis'].str.replace(' ', '')

# %%
data.dtypes
# Out:
# id                       int64
# Name_company            object
# Note trust pilot        object
# Nombre avis             object
# Localisation company    object
# Domaine d activite      object
# dtype: object

# %%
data['Nombre avis']
# Out:
# 0       5257
# 1      60705
# 2      17591
# 3       6269
# 4        498
#        ...
# 175       80
# 176       34
# 177       30
# 178       28
# 179       75
# Name: Nombre avis, Length: 180, dtype: object

# %%
data.head()
# Out:
#    id        Name_company Note trust pilot Nombre avis  \
# 0   0            Immopret              4.9        5257
# 1   1     Younited Credit              4.8       60705
# 2   2             Cofidis              4.8       17591
# 3   3  Empruntis l'agence              4.8        6269
# 4   4       CIB Formation              4.8         498
#
#       Localisation company       Domaine d activite
# 0                    Lille                   Banque
# 1                    Paris  Agence de credit*Banque
# 2  Villeneuve d'Ascq Cedex                   Banque
# 3        Saint Denis Cedex                   Banque
# 4            SAINT ETIENNE                   Banque

# %%
data.to_csv('inf_company.csv',index=False)
